# %%
import sys
sys.path.append('../')
sys.path.append('../../')

# %%
dataset_path = 'dataset/'
preprocessed_dataset_path = "preprocessed_dataset/"

# %%
from codes.docs.analysis import data_preprocessing, data_exploration, visualisation, data_preprocessing_high_dimension
from codes.docs.analysis.gene_analysis import genetic_file_preprocess

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from collections import defaultdict
# %matplotlib inline
import tqdm

import statsmodels.api as sm
import statsmodels.formula.api as sfm

from scipy.stats import ttest_ind, pearsonr,zscore
import pandas as pd
import re

# %%
european_volumetric_dataset_term = pd.read_csv(
    preprocessed_dataset_path +
    'imaging_data/volumetric/term/european_volumetric_df.csv')
mixed_volumetric_dataset_term = pd.read_csv(
    preprocessed_dataset_path +
    'imaging_data/volumetric/term/mixed_volumetric_df.csv')

# %%
dHCP_outcomes = pd.read_csv(f'../../{dataset_path}participant_outcome/DHCPNDH1-LeHaiOutcome_DATA_LABELS_2022-06-09_0947.csv')
dHCP_outcomes_CBCL_Bayley = dHCP_outcomes.iloc[:,np.r_[0,4,11:13,13,16:19,21:24,34,56,77:92]].copy()
dHCP_outcomes_CBCL_Bayley = dHCP_outcomes.iloc[:,np.r_[0,4,11:13,13,18,23,83:90]].copy()
dHCP_outcomes_CBCL_Bayley = dHCP_outcomes.iloc[:,np.r_[0,4,11:13,83:90]].copy()
dHCP_outcomes_CBCL_Bayley = dHCP_outcomes.iloc[:,np.r_[0,4,11:13,13,18,23,72]].copy()
dHCP_outcomes_CBCL_Bayley['Assessment Age'] = dHCP_outcomes_CBCL_Bayley['Corrected Age - Months'] + dHCP_outcomes_CBCL_Bayley['Corrected Age - Days']/30
dHCP_outcomes_CBCL_Bayley.rename(columns={'IMD Score':'IMD'},inplace=True)
dHCP_outcomes_CBCL_Bayley = dHCP_outcomes_CBCL_Bayley.dropna()
dHCP_total_QCHAT_SCORE = dHCP_outcomes.iloc[:,np.r_[0,72]]

# %%
european_volumetric_dataset_term = european_volumetric_dataset_term.merge(dHCP_outcomes_CBCL_Bayley,
                                                                          left_on='ID',
                                                                          right_on='Participant ID',how='inner')

# %%
mixed_volumetric_dataset_term = mixed_volumetric_dataset_term.merge(dHCP_outcomes_CBCL_Bayley,
                                                                          left_on='ID',
                                                                          right_on='Participant ID',how='inner')

# %%
df = european_volumetric_dataset_term.copy()

# %%
df = mixed_volumetric_dataset_term.copy()

# %%
cols = [i for i in df.columns if 'score' in i.lower()]
df = data_exploration.MassUnivariate.remove_outliers(df,
                                                        col=cols,
                                                         threshold=3,
                                                        remove_schemes='sum',
                                                        percentage_of_outlier=0.1)

# %%
cols = [i for i in df.columns if 'score' in i.lower()]

pca, prs_cognitive_score, loadings = data_preprocessing_high_dimension.FeatureReduction.perform_PCA(df = df,
                                                              dependentVar_cols=cols,
                                                                                     n_components=.8,scaling=True)

# %%
# dependentVar_cols=[i for i in combined.columns if bool(re.search('Imperial \d',i))]
# dependentVar_cols = data_preprocessing.Volumes.extract_GM_Imperial(dependentVar_cols)
# df = european_volumetric_dataset_term
dependentVar_cols = [
    i for i in df.columns
    if bool(re.search('AAL \d', i))
]
pca, X_pca, brain_loading_matrix = data_preprocessing_high_dimension.FeatureReduction.perform_PCA(
    df=df,
    dependentVar_cols=dependentVar_cols,
    scaling=True,n_components = .8)

# %%
# prs_lds = ['All_LD','AllLDimputed','Euro_LD','EuroLDimputed']
prs_lds = ['PRS']
for threshold in prs_lds:
    _,prs_pca,_ = data_preprocessing_high_dimension.FeatureReduction.perform_PCA(
    df = df,
    dependentVar_cols=[i for i in df.columns if threshold in i],
    scaling=True,
    n_components=1)
    for i in range(prs_pca.shape[1]):
        df[f'prs_pca_{threshold}_PC{i}'] = prs_pca[:,i]

# %%
thresholds = [i for i in df.columns if 'PRS' in i]
# ancestry = ['mixed_Anc_PC' + str(i) for i in range(1, 31)]
ancestry = ['euro_Anc_PC' + str(i) for i in range(1, 4)]

european_volumetric_term_mass_univariate = data_exploration.MassUnivariate.calculate_mass_univariate_across_multiple_thresholds(
    df,
    thresholds=thresholds,
    cat_independentVar_cols=['Gender'],
    cont_independentVar_cols=['Assessment Age','IMD']+ancestry,
    dependentVar_cols=cols)
# Out:
# 100%|███████████████████████████| 12/12 [00:00<00:00, 47.05it/s]

# %%
df['prs_pca'] = prs_pca

# %%
combined = np.corrcoef(df[cols],rowvar=False)
data_exploration.matSpDLite(combined)
# Out:
# Effective Number of Independent Variables [Veff] is 3.4905881524687623
# Effective Number of Independent Variables [VeffLi] (Using equation 5 of Li and Ji 2005) is 3.0
# The adjusted multiple testing correction p-val is alpha/lower(Meff) = 0.016666666666666673
# 2.9999999999999987

# %%
df.shape
# Out:
# (177, 4522)

# %%
european_volumetric_term_mass_univariate.sort_values(by='PRS_pval')
# Out:
#                          Connection  const_coef     const_pval  \
# 46          Sum Motor Scaled Scores   21.074072  2.379916e-120
# 30          Sum Motor Scaled Scores   20.999879  1.614657e-120
# 26          Sum Motor Scaled Scores   21.045220  2.951485e-120
# 18          Sum Motor Scaled Scores   21.139417  8.771583e-119
# 14          Sum Motor Scaled Scores   21.084416  1.618656e-119
# 17  Sum Communication Scaled Scores   19.924204   6.105669e-91
# 34          Sum Motor Scaled Scores   20.974416  3.959194e-120
# 19                Total QCHAT Score   28.908063   2.043683e-76
# 42          Sum Motor Scaled Scores   21.004685  4.556881e-120
# 38          Sum Motor Scaled Scores   20.998446  4.734598e-120
# 8            Cognitive Scaled Score   10.281074  1.422604e-103
# 22          Sum Motor Scaled Scores   21.051272  1.816082e-119
# 5   Sum Communication Scaled Scores   19.780564   5.499893e-92
# 16           Cognitive Scaled Score   10.364272  7.145528e-102
# 4            Cognitive Scaled Score   10.271007  6.341583e-103
# 1   Sum Communication Scaled Scores   19.748596   8.229915e-92
# 45  Sum Communication Scaled Scores   19.780869   1.888897e-91
# 13  Sum Communication Scaled Scores   19.793510   5.505379e-91
# 21  Sum Communication Scaled Scores   19.780325   3.194518e-91
# 36           Cognitive Scaled Score   10.304650  3.172107e-103
# 3                 Total QCHAT Score   29.239727   1.937534e-78
# 34  0.069343        -0.219900         0.647186          PRS_0.1
# 19  0.071502        -0.806277         0.535964       PRS_0.0001
# 42  0.072432        -0.283681         0.556798            PRS_1
# 38  0.080242        -0.270534         0.574955          PRS_0.5
# 8   0.089762         0.598214         0.046528        PRS_1e-06
# 22  0.092070        -0.381847         0.438753        PRS_0.001
# 5   0.119436         1.605241         0.020003        PRS_1e-07
# 16  0.177070         0.422903         0.185036       PRS_0.0001
# 4   0.240448         0.619427         0.041905        PRS_1e-07
# 1   0.244432         1.672601         0.015288        PRS_1e-08
# 45  0.264221         1.604597         0.021658  prs_pca_PRS_PC0
# 13  0.320173         1.577962         0.025982        PRS_1e-05
# 21  0.326917         1.605744         0.022351        PRS_0.001
# 36  0.401106         0.548535         0.069994          PRS_0.5
# 3   0.417718        -1.505140         0.225917        PRS_1e-08
# 0   0.435167         0.593967         0.050448        PRS_1e-08
# 40  0.451604         0.547768         0.070820            PRS_1
# 25  0.459134         1.674090         0.016193         PRS_0.01
# 32  0.477092         0.564753         0.061508          PRS_0.1
# 28  0.478850         0.555166         0.066553         PRS_0.05
# 24  0.565532         0.541875         0.076407         PRS_0.01
# 10  0.569084        -0.215656         0.656815        PRS_1e-06
# 33  0.587863         1.746698         0.011217          PRS_0.1
# 41  0.589360         1.719544         0.012902            PRS_1
# 44  0.610102         0.539253         0.079816  prs_pca_PRS_PC0
# 37  0.627610         1.727441         0.012416          PRS_0.5
# 7   0.659165        -1.532095         0.220456        PRS_1e-07
# 20  0.663933         0.540385         0.080800        PRS_0.001
# 23  0.694755        -1.717514         0.176031        PRS_0.001
# 27  0.698772        -1.685849         0.179031         PRS_0.01
# 15  0.722281        -1.494400         0.242868        PRS_1e-05
# 29  0.804874         1.743632         0.011579         PRS_0.05
# 6   0.805985        -0.216952         0.657813        PRS_1e-07
# 2   0.831235        -0.189364         0.697739        PRS_1e-08
# 39  0.845918        -1.629209         0.190071          PRS_0.5
# 43  0.846296        -1.632274         0.189753            PRS_1
# 12  0.853057         0.584141         0.061617        PRS_1e-05
# 47  0.859727        -1.565983         0.214908  prs_pca_PRS_PC0
# 31  0.881260        -1.596678         0.198519         PRS_0.05
# 35  0.924005        -1.611841         0.193426          PRS_0.1
# 9   0.952710         1.752769         0.011116        PRS_1e-06
# 11  0.965665        -1.606181         0.195588        PRS_1e-06

# %%
ylabel='Sum Motor Scaled Scores'
xlabel = 'PRS_pca'
model1, _ = data_exploration.MassUnivariate.mass_univariate(
    df,
    cat_independentVar_cols=['Gender'],
    cont_independentVar_cols=['IMD','Assessment Age']+ancestry,
    dependentVar_cols=[ylabel])
# model2, _ = data_exploration.MassUnivariate.mass_univariate(
#     df,
#     cont_independentVar_cols=ancestry,
#     dependentVar_cols=['prs_pca'])
# ax = plt.subplot(111)
visualisation.simple_plots.plot_Linear_Reg(prs_pca, model1.resid, xlabel=f'Adj. {xlabel}', ylabel=f'Adj. {ylabel}',markersize=5,scaling='both')
sns.despine(left=True,right=True,bottom=True,top=True)

# %%
full_cohort = genetic_file_preprocess.Cohort.preprocess_PRSice_PRS_Anc_files('../../dataset/ancestry_PCs/file3_all_pca.eigenvec')

# %%
thresholds = [i for i in df.columns if 'PRS' in i]
# ancestry = ['mixed_Anc_PC' + str(i) for i in range(1, 31)]
ancestry = ['euro_Anc_PC' + str(i) for i in range(1, 4)]

european_volumetric_term_mass_univariate = data_exploration.MassUnivariate.calculate_mass_univariate_across_multiple_thresholds(
    df,
    thresholds=thresholds,
    cat_independentVar_cols=['Gender'],
    cont_independentVar_cols=['GA_vol','PMA_vol','17 TOTAL BRAIN TISSUE VOLUME (mm3)']+ancestry,
    dependentVar_cols=X_pca)
# Out:
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 40.63it/s]

# %%
european_volumetric_term_mass_univariate.sort_values(by='PRS_pval')
# Out:
#          Connection  const_coef  const_pval  GA_vol_coef  GA_vol_pval  \
# 69  Dependent_Var_3   -0.042817    0.730150    -0.183263     0.101776
# 27  Dependent_Var_3   -0.012534    0.920887    -0.187398     0.095802
# 51  Dependent_Var_3   -0.077430    0.535414    -0.191844     0.090742
# 39  Dependent_Var_3   -0.059102    0.637656    -0.181773     0.109005
# 3   Dependent_Var_3   -0.082012    0.513019    -0.151316     0.183958
# ..              ...         ...         ...          ...          ...
# 50  Dependent_Var_2    0.052977    0.722943    -0.129931     0.336947
# 2   Dependent_Var_2    0.052597    0.724841    -0.126505     0.350902
# 12  Dependent_Var_0   -0.227796    0.059213     0.116419     0.284080
# 49  Dependent_Var_1    0.190361    0.239213    -0.046980     0.747633
# 24  Dependent_Var_0   -0.226974    0.064646     0.115951     0.286096
#
#     PMA_vol_coef  PMA_vol_pval  17 TOTAL BRAIN TISSUE VOLUME (mm3)_coef  \
# 69      0.930728  1.738682e-07                                -0.562188
# 27      0.912244  3.420203e-07                                -0.552828
# 51      0.964241  8.881269e-08                                -0.593606
# 39      0.931723  2.380463e-07                                -0.575809
# 3       0.887547  1.097221e-06                                -0.535864
# ..           ...           ...                                      ...
# 50      0.351204  9.050128e-02                                -0.261385
# 2       0.344621  1.013588e-01                                -0.256378
# 12     -0.043641  7.935676e-01                                 8.180572
# 49     -0.245112  2.729584e-01                                 0.161008
# 24     -0.042829  7.971348e-01                                 8.179857
#
#     17 TOTAL BRAIN TISSUE VOLUME (mm3)_pval  euro_Anc_PC1_coef  \
# 69                             1.776078e-04          -0.019090
# 27                             2.460324e-04           0.001262
# 51                             8.878286e-05          -0.009461
# 39                             1.487782e-04          -0.001850
# 3                              4.929687e-04           0.008854
# ..                                      ...                ...
# 50                             1.412136e-01          -0.001561
# 2                              1.557218e-01          -0.000067
# 12                            4.009784e-112          -0.020179
# 49                             4.005068e-01           0.105439
# 24                            4.011631e-112          -0.020267
#
#     euro_Anc_PC1_pval  euro_Anc_PC2_coef  euro_Anc_PC2_pval  \
# 69           0.826791           0.009318           0.914707
# 27           0.988442          -0.006488           0.940593
# 51           0.914419           0.008371           0.924285
# 39           0.983227           0.005973           0.946015
# 3            0.919835          -0.007027           0.936338
# ..                ...                ...                ...
# 50           0.988174          -0.139518           0.186707
# 2            0.999490          -0.140748           0.180835
# 12           0.810898           0.062616           0.457923
# 49           0.354762           0.034125           0.764423
# 24           0.810211           0.062566           0.458408
#
#     euro_Anc_PC3_coef  euro_Anc_PC3_pval  PRS_coef  PRS_pval  Gender_2.0_coef  \
# 69           0.009796           0.907680 -0.274197  0.001858         0.090221
# 27           0.008347           0.921611 -0.264757  0.003857         0.026410
# 51          -0.010308           0.903539 -0.213426  0.013564         0.163156
# 39           0.003044           0.971606 -0.204659  0.019778         0.124536
# 3            0.008198           0.923996 -0.195164  0.026505         0.172812
# ..                ...                ...       ...       ...              ...
# 50           0.036287           0.721474 -0.017497  0.864473        -0.111631
# 2            0.037904           0.711468 -0.016874  0.871253        -0.110829
# 12           0.051823           0.528405 -0.006830  0.933750         0.479999
# 49          -0.153878           0.162857 -0.005994  0.956837        -0.401118
# 24           0.051454           0.531298 -0.003065  0.972100         0.478266
#
#     Gender_2.0_pval        threshold
# 69         0.641228  prs_pca_PRS_PC0
# 27         0.894333       PRS_0.0001
# 51         0.400760          PRS_0.1
# 39         0.523962         PRS_0.01
# 3          0.375149        PRS_1e-08
# ..              ...              ...
# 50         0.630645          PRS_0.1
# 2          0.633071        PRS_1e-08
# 12         0.010835        PRS_1e-06
# 49         0.111000          PRS_0.1
# 24         0.013842       PRS_0.0001
#
# [72 rows x 20 columns]

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5))
ylabel='Brain_PC4'
xlabel = 'PRS_pca'
model1, _ = data_exploration.MassUnivariate.mass_univariate(
    df,
    cat_independentVar_cols=['Gender'],
    cont_independentVar_cols=['GA_vol','PMA_vol','17 TOTAL BRAIN TISSUE VOLUME (mm3)']+ancestry,
    dependentVar_cols=X_pca[:,3])
# model2, _ = data_exploration.MassUnivariate.mass_univariate(
#     df,
#     cont_independentVar_cols=ancestry,
#     dependentVar_cols=['prs_pca'])
# ax = plt.subplot(111)
visualisation.plot_Linear_Reg(prs_pca, model1.resid, xlabel=f'Adj. {xlabel}', ylabel=f'Adj. {ylabel}',markersize=5,scaling='both',legend_loc='inside',ax=axes[0])
ylabel = 'Sum Motor Scaled Scores'
model2, _ =data_exploration.MassUnivariate.mass_univariate(
    df,
    cat_independentVar_cols=['Gender'],
    cont_independentVar_cols=['IMD','Assessment Age']+ancestry,
    dependentVar_cols=[ylabel])
visualisation.plot_Linear_Reg(prs_pca, model2.resid, xlabel=f'Adj. {xlabel}', ylabel=f'Adj. {ylabel}',markersize=5,scaling='both',legend_loc='inside',ax=axes[1])
sns.despine(left=True,right=True,bottom=True,top=True)

fig.savefig('./PCAplot_with_scores.png')

# %%
data_exploration.MassUnivariate.calculate_R_squared_explained(df,
                                                              cat_independentVar_cols=['Gender'],
                                                              cont_independentVar_cols=['IMD','Assessment Age','prs_pca']+ancestry,
                                                              dependentVar_cols='Sum Motor Scaled Scores',col_to_drop=['prs_pca']
                                                             )
# Out:
# 0.03343790750376563

# %%
to_plot = european_volumetric_term_mass_univariate[european_volumetric_term_mass_univariate['Connection'] == 'Sum Motor Scaled Scores'].copy()

# %%
visualisation.simple_plots.Barplot(x='threshold',
                                  y='PRS_pval',
                                  colorby='PRS_coef',
                                   data=to_plot,
                                  rotation_x=90,
                                  cmap='Blues',
                                   hline=0.02,
                                   yscalelog=True,
                                   cmap_reversed=True,
                                  order={'x':to_plot['threshold'].tolist()})
sns.despine(bottom=True,left=True)

# %%
european_volumetric_dataset_term = european_volumetric_dataset_term.merge(
    dHCP_outcomes_CBCL_Bayley,
    left_on='ID',
    right_on='Participant ID',
    how='inner')

mixed_volumetric_dataset_term = mixed_volumetric_dataset_term.merge(
    dHCP_outcomes_CBCL_Bayley,
    left_on='ID',
    right_on='Participant ID',
    how='inner')

# %%
european_volumetric_dataset_term, _ = genetic_file_preprocess.Cohort.remove_outliers(european_volumetric_dataset_term,
                                               ancestry_PCs=['CBCL Externalising t-score','CBCL Internalising t-Score'])

mixed_volumetric_dataset_term, _ = genetic_file_preprocess.Cohort.remove_outliers(mixed_volumetric_dataset_term,
                                               ancestry_PCs=['CBCL Externalising t-score','CBCL Internalising t-Score'])

# %%
df = european_volumetric_dataset_term
ancestry_list = [f'euro_Anc_PC{i}' for i in range(1,4)]
cols = [i for i in df.columns if 'score' in i.lower()]
euro_outcome_mass_univariate = data_exploration.MassUnivariate.calculate_mass_univariate_across_multiple_thresholds(df = df,
                                                                                                                  thresholds = [i for i in df.columns if 'PRS' in i],
                                               cat_independentVar_cols=['Gender'],
                                               cont_independentVar_cols=['Corrected Age - Months','IMD']+ancestry_list,
                                                                                                                  
                                               dependentVar_cols=cols)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 17.47it/s]

# %%
euro_outcome_mass_univariate.sort_values(by='PRS_pval').groupby('Connection').head(1).head(100)
# Out:
#                                     Connection  const_coef  const_pval  \
# 249         Aggressive Behaviour Score T score   -0.066367    0.524158
# 69                      Cognitive Scaled Score   -0.148584    0.156619
# 217               DSM Anxiety Problems T score   -0.010785    0.917156
# 196                  DSM ADHD Problems T score    0.058037    0.578987
# 80           DSM Pervasive Development T score    0.072019    0.490887
# 16            Somatic Complaints Score T score   -0.041614    0.692364
# 239             DSM Affective Problems T score    0.000892    0.993174
# 97                    Gross Motor Scaled Score    0.129453    0.218495
# 29                     Sum Motor Scaled Scores    0.036066    0.731114
# 222            Anxious/Depressed Score T score   -0.058207    0.582478
# 183                 CBCL Externalising t-score    0.046265    0.659276
# 136                 CBCL Internalising t-Score   -0.012136    0.908830
# 116       Receptive Communication Scaled Score   -0.159887    0.125361
# 36   DSM Oppositional/Defiant Problems T score    0.022947    0.828398
# 76                           Total QCHAT Score    0.100923    0.341732
# 129         Emotionally Reactive Score T score    0.046647    0.659280
# 201                    Withdrawn Score T score    0.016137    0.878023
# 156           Attention Problems Score T score    0.102460    0.333108
# 188                    Fine Motor Scaled Score   -0.075294    0.471173
# 169                         CBCL Total t-Score    0.051499    0.626801
# 222           0.628713          -0.018712           0.809653  0.077534
# 183           0.703252           0.032205           0.675452 -0.075152
# 136           0.653773           0.078749           0.306454 -0.069277
# 116           0.110043          -0.048885           0.517135 -0.067882
# 36            0.442221          -0.080525           0.294178 -0.068641
# 76            0.423327          -0.011358           0.882210  0.061431
# 129           0.527405           0.098989           0.198132 -0.059838
# 201           0.361784          -0.003844           0.960356 -0.058931
# 156           0.675306           0.004168           0.956694  0.055859
# 188           0.696402          -0.005495           0.942964  0.053268
# 169           0.938039           0.037129           0.632512 -0.053536
# 135           0.734511          -0.014126           0.854998 -0.047991
# 140           0.119207          -0.116537           0.119613  0.035977
# 118           0.074426          -0.088825           0.235243 -0.033781
#
#      PRS_pval  Gender_2.0_coef  Gender_2.0_pval   threshold
# 249  0.086110         0.139846         0.357567       PRS_1
# 69   0.089776         0.313088         0.041683   PRS_1e-05
# 217  0.121520         0.022725         0.880499     PRS_0.5
# 196  0.148882        -0.122292         0.422864     PRS_0.1
# 80   0.184193        -0.151755         0.320763   PRS_1e-05
# 16   0.192004         0.087688         0.567693   PRS_1e-08
# 239  0.219642        -0.001880         0.990134       PRS_1
# 97   0.300132        -0.272777         0.076556  PRS_0.0001
# 29   0.320260        -0.075996         0.619679   PRS_1e-07
# 222  0.330323         0.122651         0.427070     PRS_0.5
# 183  0.340087        -0.097487         0.524375    PRS_0.05
# 136  0.376042         0.025572         0.868804   PRS_0.001
# 116  0.376579         0.336905         0.027626   PRS_0.001
# 36   0.376817        -0.048352         0.754217   PRS_1e-07
# 76   0.429703        -0.212660         0.170889   PRS_1e-05
# 129  0.443483        -0.098291         0.524914   PRS_0.001
# 201  0.457306        -0.034004         0.824481     PRS_0.1
# 156  0.477395        -0.215898         0.163980    PRS_0.01
# 188  0.498622         0.158656         0.298127     PRS_0.1
# 169  0.500462        -0.108517         0.482675    PRS_0.05
# 135  0.541640        -0.031202         0.841112   PRS_0.001
# 140  0.637656         0.353980         0.019520    PRS_0.01
# 118  0.656475         0.390208         0.010180   PRS_0.001

# %%
df = mixed_volumetric_dataset_term
ancestry_list = [f'mixed_Anc_PC{i}' for i in range(1,6)]
cols = [i for i in df.columns if 'scaled' in i.lower()]
mixed_outcome_mass_univariate = data_exploration.MassUnivariate.calculate_mass_univariate_across_multiple_thresholds(df = df,
                                                                                                                  thresholds = [i for i in df.columns if 'PRS' in i],
                                               cat_independentVar_cols=['Gender'],
                                               cont_independentVar_cols=['Corrected Age - Months','IMD']+ancestry_list,
                                                                                                                  
                                               dependentVar_cols=['Parenting Style','Parenting Style.1'])
mixed_outcome_mass_univariate.sort_values(by='PRS_pval').groupby('Connection').head(5)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 63.31it/s]
#            Connection  const_coef  const_pval  Corrected Age - Months_coef  \
# 10    Parenting Style   -0.011774    0.896357                    -0.227122
# 12    Parenting Style   -0.012493    0.890169                    -0.226033
# 18    Parenting Style   -0.007113    0.937205                    -0.226801
# 20    Parenting Style   -0.007255    0.935961                    -0.226334
# 16    Parenting Style   -0.008033    0.929121                    -0.225590
# 11  Parenting Style.1    0.103203    0.276861                     0.017587
# 19  Parenting Style.1    0.100687    0.288087                     0.017289
# 21  Parenting Style.1    0.100754    0.287766                     0.017170
# 7   Parenting Style.1    0.102077    0.282533                     0.015245
# 17  Parenting Style.1    0.101046    0.286513                     0.015560
#
#     Corrected Age - Months_pval  IMD_coef  IMD_pval  mixed_Anc_PC1_coef  \
# 10                     0.000733  0.177569  0.007809            0.032564
# 12                     0.000766  0.175675  0.008661            0.025426
# 18                     0.000753  0.175782  0.008641            0.006020
# 20                     0.000769  0.176328  0.008415            0.008642
# 16                     0.000787  0.175938  0.008610            0.015782
# 11                     0.800375  0.035393  0.610120            0.010581
# 19                     0.803803  0.036258  0.602461            0.024003
# 21                     0.805056  0.036073  0.604119            0.023624
# 7                      0.826019  0.034734  0.617247            0.003718
# 17                     0.822830  0.035050  0.614775            0.010491
#
#     mixed_Anc_PC1_pval  mixed_Anc_PC2_coef  ...  mixed_Anc_PC3_pval  \
# 10            0.667056            0.147586  ...            0.289033
# 12            0.746987            0.145081  ...            0.285223
# 18            0.947633            0.145978  ...            0.277596
# 20            0.924634            0.146295  ...            0.280905
# 16            0.854775            0.145227  ...            0.279670
# 11            0.893923           -0.100749  ...            0.986702
# 19            0.802738           -0.099943  ...            0.975393
# 21            0.805148           -0.100044  ...            0.976537
# 7             0.961807           -0.101137  ...            0.991998
# 17            0.907615           -0.100475  ...            0.997373
#
#     mixed_Anc_PC4_coef  mixed_Anc_PC4_pval  mixed_Anc_PC5_coef  \
# 10            0.093947            0.209468            0.075345
# 12            0.092057            0.219641            0.073785
# 18            0.093486            0.212084            0.070794
# 20            0.093437            0.212474            0.071097
# 16            0.093796            0.210604            0.072456
# 11            0.006096            0.937978           -0.037873
# 19            0.006282            0.936132           -0.035533
# 21            0.006378            0.935168           -0.035561
# 7             0.004898            0.950133           -0.038400
# 17            0.005476            0.944323           -0.037415
#
#     mixed_Anc_PC5_pval  PRS_coef  PRS_pval  Gender_2.0_coef  Gender_2.0_pval  \
# 10            0.282774 -0.060793  0.383035         0.025432         0.849555
# 12            0.293384 -0.060565  0.409516         0.026986         0.840768
# 18            0.315442 -0.069592  0.429453         0.015364         0.908520
# 20            0.313443 -0.065670  0.453459         0.015672         0.906711
# 16            0.303225 -0.061025  0.457839         0.017350         0.896778
# 11            0.606225  0.032942  0.651915        -0.222918         0.113894
# 19            0.630449  0.036178  0.695027        -0.217484         0.121855
# 21            0.630183  0.035712  0.697182        -0.217628         0.121604
# 7             0.601315  0.014112  0.842397        -0.220487         0.118373
# 17            0.611761  0.016556  0.847568        -0.218260         0.120646
#
#     threshold
# 10  PRS_0.001
# 12   PRS_0.01
# 18    PRS_0.5
# 20      PRS_1
# 16    PRS_0.1
# 11  PRS_0.001
# 19    PRS_0.5
# 21      PRS_1
# 7   PRS_1e-05
# 17    PRS_0.1
#
# [10 rows x 22 columns]

# %%
df = mixed_volumetric_dataset_term.copy()

# %%
prs_model,_ =  data_exploration.MassUnivariate.mass_univariate(df,
                                                          cont_independentVar_cols=ancestry_list,
                                                          dependentVar_cols=['PRS_1e-05'])
cognitive_scale_model, _ = data_exploration.MassUnivariate.mass_univariate(df,
                                                                           cat_independentVar_cols=['Gender'],
                                                          cont_independentVar_cols=ancestry_list+['Corrected Age - Months','IMD'],
                                                          dependentVar_cols=['Cognitive Scaled Score'])

# %%
visualisation.plot_Linear_Reg(x=prs_model.resid,
                             y= cognitive_scale_model.resid,
                             xlabel='PRS_1e-5',
                             ylabel='Cognitive Scale',
                             markersize=5)

# %%
cols = [i for i in df.columns if 'score' in i.lower()]

pca, X_pca, loadings = data_preprocessing_high_dimension.FeatureReduction.perform_PCA(df = df,
                                                              dependentVar_cols=cols,
                                                                                     n_components=2,scaling=True)

# %%
fig,ax = plt.subplots(1,1,figsize=(15,8))
im = ax.imshow(loadings,vmin=-1,vmax=1,cmap='jet')
ax.set_xticks(np.arange(0,len(loadings.columns),1))
ax.set_yticks(np.arange(0,len(loadings.index),1))
ax.set_xticks(np.arange(-.5, len(loadings.columns), 1), minor=True)
ax.set_yticks(np.arange(-.5, len(loadings.index), 1), minor=True)

ax.set_xticklabels(loadings.columns,rotation=45,fontsize=15)
ax.set_yticklabels(loadings.index,rotation=0,fontsize=15)
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

fig.colorbar(im, orientation='vertical')

# %%
df = mixed_volumetric_dataset_term
ancestry_list = [f'mixed_Anc_PC{i}' for i in range(1, 6)]
mixed_outcome_mass_univariate_pca = data_exploration.MassUnivariate.calculate_mass_univariate_across_multiple_thresholds(
    df=df,
    thresholds=[i for i in df.columns if 'PRS' in i],
    cat_independentVar_cols=['Gender'],
    cont_independentVar_cols=['Corrected Age - Months', 'IMD','GA_vol'] + ancestry_list,
    dependentVar_cols=X_pca)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 61.86it/s]

# %%
data_exploration.MassUnivariate.mass_univariate(df,
                                               cat_independentVar_cols=['Gender'],
                                               cont_independentVar_cols=X_pca,
                                               dependentVar_cols=['GA_vol'])
# Out:
# (<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f6a73b2edf0>,
#          const_coef  const_pval  Cont_0_coef  Cont_0_pval  Cont_1_coef  \
#  GA_vol   -0.050266    0.585835    -0.023011     0.732745    -0.185582
#
#          Cont_1_pval  Gender_2.0_coef  Gender_2.0_pval
#  GA_vol     0.006673         0.108575         0.425155  )

# %%
mixed_outcome_mass_univariate_pca.sort_values(by='PRS_pval')
# Out:
#          Connection  const_coef  const_pval  Corrected Age - Months_coef  \
# 11  Dependent_Var_1    0.076851    0.398792                    -0.030280
# 15  Dependent_Var_1    0.073967    0.416285                    -0.031083
# 17  Dependent_Var_1    0.072237    0.427387                    -0.032040
# 21  Dependent_Var_1    0.071355    0.433044                    -0.031054
# 19  Dependent_Var_1    0.071236    0.433909                    -0.031156
# 7   Dependent_Var_1    0.075979    0.404980                    -0.034373
# 13  Dependent_Var_1    0.076170    0.403983                    -0.033200
# 1   Dependent_Var_1    0.073899    0.417486                    -0.035349
# 9   Dependent_Var_1    0.075463    0.408244                    -0.033403
# 5   Dependent_Var_1    0.074477    0.414269                    -0.035397
# 3   Dependent_Var_1    0.073493    0.420157                    -0.035326
# 10  Dependent_Var_0    0.019701    0.835676                     0.023849
# 14  Dependent_Var_0    0.021727    0.818945                     0.025388
# 16  Dependent_Var_0    0.022472    0.812848                     0.026225
# 8   Dependent_Var_0    0.021341    0.822395                     0.026585
# 0   Dependent_Var_0    0.022218    0.815043                     0.027601
# 6   Dependent_Var_0    0.021962    0.817359                     0.027520
# 12  Dependent_Var_0    0.022083    0.816421                     0.027484
# 2   Dependent_Var_0    0.022881    0.809619                     0.028343
# 20  Dependent_Var_0    0.022657    0.811365                     0.027508
# 4   Dependent_Var_0    0.022827    0.810189                     0.028175
# 18  Dependent_Var_0    0.022603    0.811815                     0.028283
#
#     Corrected Age - Months_pval  IMD_coef  IMD_pval  GA_vol_coef  GA_vol_pval  \
# 11                     0.650791  0.098763  0.138822    -0.179327     0.008909
# 15                     0.641976  0.101667  0.128875    -0.179552     0.008849
# 17                     0.631809  0.100915  0.131878    -0.178523     0.009249
# 21                     0.642825  0.100383  0.133635    -0.177086     0.009790
# 19                     0.641932  0.100492  0.133499    -0.177009     0.009836
# 7                      0.606726  0.098603  0.140356    -0.179354     0.009034
# 13                     0.619710  0.099592  0.137119    -0.179216     0.009089
# 1                      0.596337  0.099049  0.139082    -0.179589     0.008994
# 9                      0.617677  0.099185  0.138699    -0.179273     0.009095
# 5                      0.596044  0.097849  0.143552    -0.178901     0.009249
# 3                      0.596825  0.098317  0.141974    -0.179005     0.009220
# 10                     0.732612 -0.023987  0.729839    -0.017862     0.801265
# 14                     0.715997 -0.024572  0.724455    -0.018223     0.797458
# 16                     0.707008 -0.023798  0.732818    -0.018798     0.791175
# 8                      0.703177 -0.023316  0.737882    -0.018498     0.794659
# 0                      0.691629 -0.022663  0.744902    -0.018853     0.790892
# 6                      0.692723 -0.022463  0.746817    -0.018989     0.789315
# 12                     0.693636 -0.022467  0.747179    -0.019101     0.788104
# 2                      0.683900 -0.021457  0.757942    -0.019775     0.780876
# 20                     0.693884 -0.022332  0.748563    -0.019384     0.784785
# 4                      0.685648 -0.021724  0.754842    -0.019590     0.782840
# 18                     0.685832 -0.021701  0.755571    -0.019437     0.784210
#
#     mixed_Anc_PC1_coef  ...  mixed_Anc_PC3_pval  mixed_Anc_PC4_coef  \
# 11           -0.178045  ...            0.107509            0.011725
# 15           -0.155621  ...            0.101586            0.013901
# 17           -0.156409  ...            0.102352            0.011902
# 21           -0.148074  ...            0.103722            0.012197
# 19           -0.150182  ...            0.104802            0.011770
# 7            -0.190262  ...            0.116657            0.009150
# 13           -0.176945  ...            0.112258            0.012686
# 1            -0.194328  ...            0.120261            0.009067
# 9            -0.188568  ...            0.114995            0.010203
# 5            -0.193057  ...            0.121702            0.009137
# 3            -0.193896  ...            0.120686            0.008872
# 10            0.016386  ...            0.467703            0.151146
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    plt.scatter(xs * scalex,ys * scaley)
    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'g', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.xlabel("PC{}".format(1))
plt.ylabel("PC{}".format(2))
myplot(CBCL_Bayley_PCA[:,0:2],np.transpose(pca.components_[0:2, :]))
plt.show()

# %%
abs(pca.explained_variance_ratio_)
# Out:
# array([0.37275812, 0.17335888, 0.14513648, 0.10322412, 0.0594611 ,
#        0.04594735, 0.03747391, 0.03270018, 0.01858531, 0.01135455])

# %%
european_volumetric_dataset_term['PC1'] = CBCL_Bayley_PCA[:,0]
european_volumetric_dataset_term['PC2'] = CBCL_Bayley_PCA[:,1]
european_volumetric_dataset_term['PC3'] = CBCL_Bayley_PCA[:,2]

# %%
plt.imshow(abs(pca.components_),cmap='coolwarm')
plt.colorbar()

# %%
list(zip(dHCP_outcomes.columns,range(len(dHCP_outcomes.columns))))
# Out:
# [('Participant ID', 0),
#  ('Event Name', 1),
#  ('Repeat Instrument', 2),
#  ('Repeat Instance', 3),
#  ('IMD Score', 4),
#  ('IMD Quintile', 5),
#  ("Child's Sex", 6),
#  ('Bayley First or Second?', 7),
#  ('Eye Tracking First or Second', 8),
#  ('Age - Months', 9),
#  ('Age - Days', 10),
#  ('Corrected Age - Months', 11),
#  ('Corrected Age - Days', 12),
#  ('Cognitive Scaled Score', 13),
#  ('Composite Score', 14),
#  ('Cognitive Rank', 15),
#  ('Receptive Communication Scaled Score', 16),
#  ('Expressive Communication Scaled Score', 17),
#  ('Sum Communication Scaled Scores', 18),
#  ('Communication Composite Score', 19),
#  ('Communication Rank', 20),
#  ('Fine Motor Scaled Score', 21),
#  ('Gross Motor Scaled Score', 22),
#  ('Sum Motor Scaled Scores', 23),
#  ('Motor Composite Score', 24),
#  ('Motor Rank', 25),
#  ('Cognition', 26),
#  ('Receptive Communication', 27),
#  ('Expressive Communication', 28),
#  ('Fine Motor', 29),
#  ('Gross Motor', 30),
#  ('Laxness', 31),
#  ('Over-reactivity', 32),
#  ('Verbosity', 33),
#  ('Parenting Style', 34),
#  ('1. Is English your first language?', 35),
#  ('2. What is your first language if not English?', 36),
#  ('3. How would you classify your ethnicity?', 37),
#  ('4. When were you last in continuous education?', 38),
#  ('5. What is your occupation', 39),
#  ('10. Have you ever been treated for a mental health problem?', 40),
#  (' 10a.Have you ever been under psychiatric services?', 41),
#  (' 10b. Have you ever been admitted to hospital for a mental health problem?',
#   42),
#  (' 10c. Do you have a history of ADHD, bipolar disease, depression, autism, or schizophrenia?',
#   43),
#  ("11. Have you or your child's biological father ever been diagnosed with Attention Deficit Hyperactivity Disorder (ADHD) or autism?",
#   44),
#  ('12. Does anyone in your close family have a history of ADHD, bipolar disease, depression, autism, or schizophrenia?',
#   45),
#  (" 12a. Baby's father", 46),
#  (" 12b. Your mother (baby's maternal grandmother)", 47),
#  (" 12c. Your father (baby's maternal grandfather)", 48),
#  (" 12d. Your baby's paternal grandmother (baby's father's mother)", 49),
#  (" 12e. Your baby's paternal grandfather (baby's father's father)", 50),
#  (" 12f. How many of your siblings, or your baby's father's siblings have a history of ADHD, bipolar disease, depression, autism, or schizophrenia?",
#   51),
#  (' Details of siblings', 52),
#  ('Laxness.1', 53),
#  ('Over-reactivity.1', 54),
#  ('Verbosity.1', 55),
#  ('Parenting Style.1', 56),
#  ('2. Is English your first language?', 57),
#  ('3. What is your first language if not English?', 58),
#  ('4. How would you classify your ethnicity?', 59),
#  ('5. When were you last in continuous education?', 60),
#  ('6. What is your occupation', 61),
#  ('7. Have you ever been treated for a mental health problem?', 62),
#  (' 7a.Have you ever been under the care of psychiatric services?', 63),
#  (' 7b. Have you ever been admitted to hospital for a mental health problem?',
#   64),
#  (' 7c. Do you have a history of ADHD, bipolar disease, depression, autism, or schizophrenia?',
#   65),
#  ("8. Have you or your child's biological mother ever been diagnosed with Attention Deficit Hyperactivity Disorder (ADHD) or autism?",
#   66),
#  ('9. Does anyone in your close family have a history of ADHD, bipolar disease, depression, autism, or schizophrenia?',
#   67),
#  (" 9a. Your mother (baby's paternal grandmother)", 68),
#  (" 9b. Your father (baby's paternal grandfather)", 69),
#  (" 9c. How many of your siblings, or your baby's mother's siblings have a history of ADHD, bipolar disease, depression, autism, or schizophrenia?",
#   70),
#  (' Details of siblings.1', 71),
#  ('Total QCHAT Score', 72),
#  ('Surgency', 73),
#  ('Negative Affect', 74),
#  ('Effortful Control', 75),
#  ('Home Environment Score', 76),
#  ('CBCL Total t-Score', 77),
#  ('DSM Affective Problems T score', 78),
#  ('DSM Anxiety Problems T score', 79),
#  ('DSM Pervasive Development T score', 80),
#  ('DSM ADHD Problems T score', 81),
#  ('DSM Oppositional/Defiant Problems T score', 82),
#  ('Emotionally Reactive Score T score', 83),
#  ('Anxious/Depressed Score T score', 84),
#  ('Somatic Complaints Score T score', 85),
#  ('Withdrawn Score T score', 86),
#  ('Attention Problems Score T score', 87),
#  ('Aggressive Behaviour Score T score', 88),
#  ('Sleep Problems Score T score', 89),
#  ('CBCL Internalising t-Score', 90),
#  ('CBCL Externalising t-score', 91)]

# %%
def calculate_mass_univariate_across_multiple_PRS_thresholds(
    df,
    cat_independentVar_cols=['Gender'],
    cont_independentVar_cols=['Corrected Age - Months'],
    dependentVar_cols=[i for i in dHCP_outcomes_CBCL.columns if 'T score' in i],
    thresholds=[
        i for i in european_volumetric_dataset_term.columns if 'PRS' in i
    ]):
    """
    Perform mass univariate tests to a range of PRS_threshold
    Args:
        see mass_univariate.
        threshold = list of PRS thresholds
    Return:
        new_df (Data Frame)
    """
    new_df = pd.DataFrame()

    for threshold in tqdm.tqdm(thresholds):
        _, temp_model_summary = data_exploration.MassUnivariate.mass_univariate(
            df,
            cat_independentVar_cols=cat_independentVar_cols,
            cont_independentVar_cols=cont_independentVar_cols + [threshold],
            dependentVar_cols=dependentVar_cols)
        

        temp_model_summary.reset_index(drop=False, inplace=True)
        temp_model_summary.rename(
            {
                'index': 'Connection',
                threshold + '_coef': 'PRS_coef',
                threshold + '_pval': 'PRS_pval'
            },
            axis=1,
            inplace=True)
        temp_model_summary['threshold'] = threshold
        new_df = new_df.append(temp_model_summary)

    new_df.reset_index(drop=True, inplace=True)
    return new_df

# %%
df = european_volumetric_dataset_term
ancestry = ['euro_Anc_PC'+str(i) for i in range(1,4)]
european_volumetric_term_mass_univariate = calculate_mass_univariate_across_multiple_PRS_thresholds(
    df,
    cat_independentVar_cols=['Gender'],
    cont_independentVar_cols=['Corrected Age - Months']+ancestry,
    dependentVar_cols=['PC1','PC2','PC3'],
    thresholds=[i for i in df.columns if 'PRS' in i])
# i for i in df.columns if 'PRS' in i

# df = mixed_volumetric_dataset_term_with_bayley_score
# ancestry = ['mixed_Anc_PC'+str(i) for i in range(1,6)]
# mixed_volumetric_term_mass_univariate = calculate_mass_univariate_across_multiple_PRS_thresholds(
#     df,
#     cat_independentVar_cols=['Gender','assessor'],
#     cont_independentVar_cols=['corr_age_at_assess_m','age_at_assess_m','imdscaore']+ancestry,
#     dependentVar_cols=['cog_scaled',
#               'rec_scaled','exp_scaled',
#               'language_sum_scaled',
#               'fm_scaled','gm_scaled',
#                'motor_sum_scaled'],
#     thresholds=[i for i in df.columns if 'PRS' in i])
# Out:
# 100%|███████████████████████████████████████████████████████| 11/11 [00:00<00:00, 42.94it/s]

# %%
european_volumetric_dataset_term, _ = genetic_file_preprocess.Cohort.remove_outliers(european_volumetric_dataset_term,
                                               ancestry_PCs=['CBCL Externalising t-score','CBCL Internalising t-Score'])

# %%
visualisation.plot_Linear_Reg(european_volumetric_dataset_term['Imperial 17']+european_volumetric_dataset_term['Imperial 18'],
                             european_volumetric_dataset_term['PC1'])

# %%
european_volumetric_term_mass_univariate.sort_values(by='PRS_pval')
# Out:
#    Connection  const_coef  const_pval  Corrected Age - Months_coef  \
# 30        PC1    0.032431    0.758859                    -0.022625
# 27        PC1    0.032420    0.759021                    -0.022207
# 24        PC1    0.031736    0.764075                    -0.020583
# 21        PC1    0.030498    0.773186                    -0.020214
# 17        PC3    0.161279    0.123162                    -0.015828
# 16        PC2    0.010918    0.918019                    -0.028439
# 19        PC2    0.010676    0.919986                    -0.027030
# 15        PC1    0.030635    0.772609                    -0.018651
# 13        PC2    0.012353    0.907329                    -0.026509
# 6         PC1    0.035100    0.740469                    -0.014087
# 31        PC2    0.014886    0.888243                    -0.021728
# 1         PC2    0.015459    0.884034                    -0.023259
# 3         PC1    0.034168    0.746977                    -0.014513
# 29        PC3    0.157779    0.130994                    -0.018402
# 19    PRS_0.01
# 15   PRS_0.001
# 13  PRS_0.0001
# 6    PRS_1e-06
# 31       PRS_1
# 1    PRS_1e-08
# 3    PRS_1e-07
# 29     PRS_0.5
# 28     PRS_0.5
# 32       PRS_1
# 4    PRS_1e-07
# 2    PRS_1e-08
# 9    PRS_1e-05
# 5    PRS_1e-07
# 25     PRS_0.1
# 18    PRS_0.01
# 20    PRS_0.01
# 23    PRS_0.05
# 7    PRS_1e-06
# 8    PRS_1e-06
# 26     PRS_0.1
# 10   PRS_1e-05
# 11   PRS_1e-05
# 12  PRS_0.0001
# 14  PRS_0.0001
# 22    PRS_0.05
# 0    PRS_1e-08

# %%
mixed_volumetric_term_mass_univariate.sort_values(by='PRS_pval').groupby('Connection').head(1).head(25)
# Out:
#              Connection  const_coef  const_pval  corr_age_at_assess_m_coef  \
# 21           cog_scaled   -0.067427    0.558008                   0.295083
# 36           rec_scaled   -0.111917    0.340437                   0.266042
# 23           exp_scaled    0.202079    0.069812                   0.157345
# 38  language_sum_scaled    0.035225    0.761216                   0.244484
# 33            gm_scaled    0.114636    0.338201                   0.191192
# 55     motor_sum_scaled    0.146095    0.216265                   0.347582
# 25            fm_scaled    0.122520    0.280888                   0.355944
#
#     corr_age_at_assess_m_pval  age_at_assess_m_coef  age_at_assess_m_pval  \
# 21                   0.048143             -0.390924              0.009366
# 36                   0.080309             -0.340153              0.025954
# 23                   0.273142             -0.175444              0.223726
# 38                   0.103747             -0.299158              0.047243
# 33                   0.216475             -0.154067              0.320404
# 55                   0.023432             -0.304879              0.047155
# 25                   0.015889             -0.317244              0.032028
#
#     imdscaore_coef  imdscaore_pval  mixed_Anc_PC1_coef  ...  \
# 21       -0.061680        0.362024            0.204098  ...
# 36       -0.034768        0.613548            0.123194  ...
# 23       -0.064850        0.320627            0.110884  ...
# 38       -0.055158        0.417812            0.132044  ...
# 33       -0.022540        0.748580            0.069765  ...
# 55       -0.043713        0.529559            0.158170  ...
# 25       -0.038638        0.562328            0.208735  ...
#
#     mixed_Anc_PC5_pval  PRS_coef  PRS_pval  Gender_2.0_coef  Gender_2.0_pval  \
# 21            0.758051 -0.151073  0.027565         0.211737         0.123402
# 36            0.849736 -0.101883  0.154686         0.191937         0.170045
# 23            0.618428  0.045398  0.490158         0.215650         0.103978
# 38            0.898154 -0.047491  0.501253         0.229329         0.097541
# 33            0.763040  0.048187  0.503537        -0.264664         0.064217
# 55            0.869906 -0.039126  0.633486        -0.113512         0.418130
# 25            0.991125 -0.028798  0.668350         0.070937         0.599741
#
#     assessor_2.0_coef  assessor_2.0_pval  assessor_3.0_coef  \
# 21          -0.088146       5.331601e-01           0.134424
# 36           0.072681       6.140346e-01          -0.174558
# 23          -0.704460       5.578815e-07          -0.090613
# 38          -0.318838       2.605438e-02          -0.149202
# 33           0.085292       5.615103e-01          -0.594201
# 55          -0.213921       1.415243e-01          -0.059248
# 25          -0.416130       3.150917e-03           0.443226
#
#     assessor_3.0_pval   threshold
# 21           0.688954   PRS_1e-05
# 36           0.609857   PRS_0.001
# 23           0.779707   PRS_1e-05
# 38           0.658973   PRS_0.001
# 33           0.090403  PRS_0.0001
# 55           0.863477    PRS_0.05
# 25           0.181662   PRS_1e-05
#
# [7 rows x 28 columns]

# %%
visualisation.plot()

# %%
dependent_variables = ['cog_scaled',
              'rec_scaled','exp_scaled',
              'language_sum_scaled',
              'fm_scaled','gm_scaled',
               'motor_sum_scaled']
fig,axes = plt.subplots(3,3,figsize=(20,10))
axes = axes.flatten()
axes[-1].remove()
axes[-2].remove()

df = european_volumetric_dataset_term_with_bayley_score
ancestry_list = ['euro_Anc_PC'+str(i) for i in range(1,4)]
threshold = 'PRS_1e-05'
for ax,dependent_variable,ylabel in zip(axes,dependent_variables,dependent_variables):
    model, _ = data_exploration.MassUnivariate.mass_univariate(df = df,
                                                              cat_independentVar_cols=['Gender','assessor'],
                                                              cont_independentVar_cols=[
                                                                  'corr_age_at_assess_m','age_at_assess_m','imdscaore'
                                                              ]+ancestry_list,
                                                              dependentVar_cols=[dependent_variable])
    visualisation.plot_Linear_Reg(x = df[[threshold]].values,
                                 y = model.resid.values,
                                 data = df,
                                 ylabel = ylabel,
                                 xlabel = f'{threshold}',
                                 axes=ax,legend_loc='inside',linewidth = 3,markersize=5)
    ax.set_ylabel(ylabel,fontsize=20)
    ax.set_xlabel(None,fontsize=20)
    ax.tick_params(axis='both',which='major',labelsize=15)
    ax.legend(loc='lower left',fontsize=12,frameon=False)
    sns.despine(bottom=True,left=True,right=True)

# %%
dependent_variables = ['cog_scaled',
              'rec_scaled','exp_scaled',
              'language_sum_scaled',
              'fm_scaled','gm_scaled',
               'motor_sum_scaled']
fig,axes = plt.subplots(3,4,figsize=(20,15))
axes = axes.flatten()
axes[-1].remove()

# df = mixed_volumetric_dataset_term_with_bayley_score
# ancestry_list = ['mixed_Anc_PC'+str(i) for i in range(1,6)]

df = european_volumetric_dataset_term_with_bayley_score
ancestry_list = ['euro_Anc_PC'+str(i) for i in range(1,4)]

thresholds = [i for i in df.columns if 'PRS' in i]
for ax,threshold in zip(axes,thresholds):
    model, _ = data_exploration.MassUnivariate.mass_univariate(df = df,
                                                              cat_independentVar_cols=['Gender','assessor'],
                                                              cont_independentVar_cols=[
                                                                  'corr_age_at_assess_m','age_at_assess_m','imdscaore'
                                                              ]+ancestry_list,
                                                              dependentVar_cols=['cog_scaled'])
    visualisation.plot_Linear_Reg(x = df[[threshold]].values,
                                 y = model.resid.values,
                                 data = df,
                                 ylabel = 'cog_scaled',
                                 xlabel = f'{threshold}',
                                 axes=ax,legend_loc='inside',linewidth = 3,markersize=5)
    ax.set_xlabel(None,fontsize=20)
    ax.set_ylabel(None,fontsize=20)
    ax.set_title(f'{threshold}',fontsize=20)
    ax.tick_params(axis='both',which='major',labelsize=15)
    ax.legend(loc='lower left',fontsize=12,frameon=False)
    sns.despine(bottom=True,left=True,right=True)

fig.savefig('cognitive_score_neonates_euro.png',dpi=300)

# %%
[0 if ]
